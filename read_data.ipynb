# %%
import pandas as pd
import numpy as np
# %matplotlib inline 
import matplotlib.pyplot as plt
#import seaborn

besoins = pd.read_excel('Donnees huiles essentielles.xlsx',  sheetname='Besoins')
symptomes = besoins['Symptome']

prix = pd.read_excel('Donnees huiles essentielles.xlsx',  sheetname='Prix')

for i in symptomes:
    print(i)
    
nb_symptomes = besoins.shape[0]
nb_huiles = besoins.shape[1]

for i in range(1,nb_huiles):
    print(besoins.columns[i])
# Out:
# Abcès
# aérophagie
# Ampoule
# Aphte
# Brûlure
# Brûlure d'estomac
# Constipation
# Bleu
# Coupure
# Courbature
# Crampe
# Diarrhée
# Entorse
# Fièvre
# Foie
# Grippe
# Hémorroïdes
# Herpès
# Hoquet
# Indigestion
# cystite
# Mal de gorge
# Mal à la tête
# Mal des transports
# Mauvaise haleine
# Nausée
# Pied d'athlète
# Piqûre d'insecte
# règles douloureuses
# rhume
# sinusite
# toux grasse
# toux sèche
# verrue
# acné
# cellulite
# cheveux gras
# cheveux ternes
# chute de cheveux
# cicatrice
# lèvres gercées
# peau grasse
# peau sèche (corps)
# peau sèche (visage)
# pellicules
# teint terne
# transpiration
# vergetures
# choc émotionnel
# décalage horaire
# déprime
# fatigue
# frilosité
# fringale
# gueule de bois
# insomnie
# nervosité
# libido en baisse
# impuissance
# manque de concentration
# stress
# Diarrhée de stress
# Ail
# Basilic exotique
# Bergamote
# Bois de rose
# Camomille matricaire
# Camomille romaine
# Cannelle
# Cannelle de Ceylan
# Carotte cultivée
# ...
